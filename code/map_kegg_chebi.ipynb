# %%
#pip install metanetx-sdk
# !pip freeze | findstr bioservices
#mnx-sdk -h

# %%
import bioservices
from bioservices import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 import bioservices
#       2 from bioservices import *
#
# ModuleNotFoundError: No module named 'bioservices'

# %%
from bioservices import *
import csv

k = KEGG(verbose=False)
map_kegg_chebi = k.conv("chebi", "compound")

with open('../data/intermediate/kegg_chebi_dict.csv', 'w') as csv_file:  
    writer = csv.writer(csv_file)
    for key, value in map_kegg_chebi.items():
       writer.writerow([key, value])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from bioservices import *
#       2 import csv
#       4 k = KEGG(verbose=False)
#
# ModuleNotFoundError: No module named 'bioservices'
